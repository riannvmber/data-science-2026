# %% [markdown]
# <a href="https://colab.research.google.com/github/riannvmber/data-science-2026/blob/main/Pertemuan5_RianRamadhan_240401010021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import library
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import seaborn as sns

# %%
# Load Dataset
sns.set_theme(style='whitegrid')
df = sns.load_dataset('tips')
print(df.shape)
df.head()
# Out:
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# buat dashboard
fig = plt.figure(figsize=(16,12))

fig.suptitle(
    'Dashboard Analisis Dataset Tips',
    fontsize=18,
    fontweight='bold'
)

gs = gridspec.GridSpec(
    2,
    2,
    figure=fig,
    hspace=0.4,
    wspace=0.35
)

ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])

# Grafik 1
avg_by_day = df.groupby('day')['total_bill'].mean()
avg_by_day.plot(kind='bar', ax=ax1)
ax1.set_title('Rata-rata Total Bill per Hari')

# Grafik 2
sns.histplot(
    data=df,
    x='total_bill',
    hue='time',
    kde=True,
    ax=ax2
)
ax2.set_title('Distribusi Total Bill')

# Grafik 3
sns.boxplot(
    data=df,
    x='day',
    y='total_bill',
    hue='sex',
    ax=ax3
)
ax3.set_title('Distribusi Tagihan')

# Grafik 4
sns.scatterplot(
    data=df,
    x='total_bill',
    y='tip',
    hue='time',
    size='size',
    ax=ax4
)

sns.regplot(
    data=df,
    x='total_bill',
    y='tip',
    scatter=False,
    color='gray',
    ax=ax4
)

ax4.set_title('Hubungan Tagihan dan Tip')

plt.show()
# Out:
# /tmp/ipykernel_2502/2349135099.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_by_day = df.groupby('day')['total_bill'].mean()
